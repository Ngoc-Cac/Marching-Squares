# %%
import matplotlib.pyplot as plt
from square_marcher import SquareMarcher

# %%
n = 100
dim = (n, n)
marcher = SquareMarcher(dim, seed=0)

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111)
ax.axis('off')
ax.invert_yaxis()

marcher.run(ax, z=None,
            speed=.05)
pass
